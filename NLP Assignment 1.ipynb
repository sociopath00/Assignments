# %%
from nltk.corpus import wordnet

# %%
words=[["computer","keyboard"],["Jerusalem","Israel"],["planet","galaxy"],["canyon","landscape"],["OPEC","Country"],
       ["day","summer"],["day","dawn"],["country","citizen"],["planet","people"],["environment","ecology"],["Maradona","Football"],
       ["OPEC","oil"],["money","bank"],["computer","software"],["law","lawyer"],["wheather","forecast"],["network","hardware"],
       ["nature","environment"],["FBI","investigation"],["money","wealth"],["psychology","Freud"],["news","report"],
       ["war","troops"],["physics","proton"],["bank","money"],["stock","market"],["planet","constellation"],["credit","card"],
       ["hotel","reservation"],["closet","clothes"],["soap","opera"],["planet","astronomer"],["planet","space"],
       ["movie","theater"],["treatment","recovery"],["baby","mother"],["money","deposite"],["television","film"],
       ["psychology","mind"],["game","team"],["admission","ticket"],["Jerusalem","Palestinian"],["Arafat","terror"],
       ["boxing","round"],["computer","internet"],["money","property"],["tennis","racket"],["telephone","communication"],
       ["currency","market"],["psychology","cognition"]]

# %%
for w in words:
    try: 
        temp1=wordnet.synset(w[0]+".n.01")
        temp2=wordnet.synset(w[1]+".n.01")
        print("First Word: ",w[0])
        print("Second Word: ",w[1])
        print("Path similarity: ",wordnet.path_similarity(temp1,temp2))
        print("lch similarity: ",wordnet.lch_similarity(temp1,temp2))
        print("wup similarity: ",wordnet.wup_similarity(temp1,temp2))
        
    except Exception:
        print("Word not found in Wordnet")
        continue
# Out:
# First Word:  computer
# Second Word:  keyboard
# Path similarity:  0.25
# lch similarity:  2.2512917986064953
# wup similarity:  0.8235294117647058
# First Word:  Jerusalem
# Second Word:  Israel
# Path similarity:  0.14285714285714285
# lch similarity:  1.6916760106710724
# wup similarity:  0.7
# First Word:  planet
# Second Word:  galaxy
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.16666666666666666
# First Word:  canyon
# Second Word:  landscape
# Path similarity:  0.07692307692307693
# lch similarity:  1.072636802264849
# wup similarity:  0.3333333333333333
# First Word:  OPEC
# Second Word:  Country
# Path similarity:  0.14285714285714285
# lch similarity:  1.6916760106710724
# wup similarity:  0.625
# First Word:  day
# Second Word:  summer
# Path similarity:  0.14285714285714285
# lch similarity:  1.6916760106710724
# wup similarity:  0.5
# First Word:  day
# Second Word:  dawn
# Path similarity:  0.08333333333333333
# lch similarity:  1.1526795099383855
# wup similarity:  0.26666666666666666
# First Word:  country
# Second Word:  citizen
# Path similarity:  0.07692307692307693
# lch similarity:  1.072636802264849
# wup similarity:  0.14285714285714285
# First Word:  planet
# Second Word:  people
# Path similarity:  0.1
# lch similarity:  1.3350010667323402
# wup similarity:  0.18181818181818182
# First Word:  environment
# Second Word:  ecology
# Path similarity:  0.5
# lch similarity:  2.9444389791664407
# wup similarity:  0.9230769230769231
# Word not found in Wordnet
# First Word:  OPEC
# Second Word:  oil
# Path similarity:  0.06666666666666667
# lch similarity:  0.9295359586241757
# wup similarity:  0.2222222222222222
# First Word:  money
# Second Word:  bank
# Path similarity:  0.08333333333333333
# lch similarity:  1.1526795099383855
# wup similarity:  0.15384615384615385
# First Word:  computer
# Second Word:  software
# Path similarity:  0.0625
# lch similarity:  0.8649974374866046
# wup similarity:  0.11764705882352941
# First Word:  law
# Second Word:  lawyer
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.16666666666666666
# Word not found in Wordnet
# First Word:  network
# Second Word:  hardware
# Path similarity:  0.08333333333333333
# lch similarity:  1.1526795099383855
# wup similarity:  0.15384615384615385
# First Word:  nature
# Second Word:  environment
# Path similarity:  0.16666666666666666
# lch similarity:  1.845826690498331
# wup similarity:  0.5454545454545454
# First Word:  FBI
# Second Word:  investigation
# Path similarity:  0.058823529411764705
# lch similarity:  0.8043728156701697
# wup similarity:  0.2
# First Word:  money
# Second Word:  wealth
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.2857142857142857
# First Word:  psychology
# Second Word:  Freud
# Path similarity:  0.05
# lch similarity:  0.6418538861723948
# wup similarity:  0.09523809523809523
# First Word:  news
# Second Word:  report
# Path similarity:  0.125
# lch similarity:  1.55814461804655
# wup similarity:  0.46153846153846156
# First Word:  war
# Second Word:  troops
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.2857142857142857
# First Word:  physics
# Second Word:  proton
# Path similarity:  0.05
# lch similarity:  0.6418538861723948
# wup similarity:  0.09523809523809523
# First Word:  bank
# Second Word:  money
# Path similarity:  0.08333333333333333
# lch similarity:  1.1526795099383855
# wup similarity:  0.15384615384615385
# First Word:  stock
# Second Word:  market
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.2857142857142857
# First Word:  planet
# Second Word:  constellation
# Path similarity:  0.07142857142857142
# lch similarity:  0.9985288301111273
# wup similarity:  0.13333333333333333
# First Word:  credit
# Second Word:  card
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.2857142857142857
# First Word:  hotel
# Second Word:  reservation
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.375
# First Word:  closet
# Second Word:  clothes
# Path similarity:  0.125
# lch similarity:  1.55814461804655
# wup similarity:  0.5882352941176471
# First Word:  soap
# Second Word:  opera
# Path similarity:  0.06666666666666667
# lch similarity:  0.9295359586241757
# wup similarity:  0.2222222222222222
# First Word:  planet
# Second Word:  astronomer
# Path similarity:  0.1
# lch similarity:  1.3350010667323402
# wup similarity:  0.47058823529411764
# First Word:  planet
# Second Word:  space
# Path similarity:  0.1
# lch similarity:  1.3350010667323402
# wup similarity:  0.18181818181818182
# First Word:  movie
# Second Word:  theater
# Path similarity:  0.14285714285714285
# lch similarity:  1.6916760106710724
# wup similarity:  0.625
# First Word:  treatment
# Second Word:  recovery
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.4444444444444444
# First Word:  baby
# Second Word:  mother
# Path similarity:  0.1111111111111111
# lch similarity:  1.4403615823901665
# wup similarity:  0.5
# Word not found in Wordnet
# First Word:  television
# Second Word:  film
# Path similarity:  0.1111111111111111
# lch similarity:  1.4403615823901665
# wup similarity:  0.5555555555555556
# First Word:  psychology
# Second Word:  mind
# Path similarity:  0.14285714285714285
# lch similarity:  1.6916760106710724
# wup similarity:  0.5714285714285714
# First Word:  game
# Second Word:  team
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.2857142857142857
# First Word:  admission
# Second Word:  ticket
# Path similarity:  0.07142857142857142
# lch similarity:  0.9985288301111273
# wup similarity:  0.23529411764705882
# First Word:  Jerusalem
# Second Word:  Palestinian
# Path similarity:  0.0625
# lch similarity:  0.8649974374866046
# wup similarity:  0.2857142857142857
# First Word:  Arafat
# Second Word:  terror
# Path similarity:  0.06666666666666667
# lch similarity:  0.9295359586241757
# wup similarity:  0.125
# First Word:  boxing
# Second Word:  round
# Path similarity:  0.05555555555555555
# lch similarity:  0.7472144018302211
# wup similarity:  0.10526315789473684
# First Word:  computer
# Second Word:  internet
# Path similarity:  0.125
# lch similarity:  1.55814461804655
# wup similarity:  0.631578947368421
# First Word:  money
# Second Word:  property
# Path similarity:  0.1111111111111111
# lch similarity:  1.4403615823901665
# wup similarity:  0.3333333333333333
# First Word:  tennis
# Second Word:  racket
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.4444444444444444
# First Word:  telephone
# Second Word:  communication
# Path similarity:  0.07142857142857142
# lch similarity:  0.9985288301111273
# wup similarity:  0.13333333333333333
# First Word:  currency
# Second Word:  market
# Path similarity:  0.09090909090909091
# lch similarity:  1.2396908869280152
# wup similarity:  0.2857142857142857
# First Word:  psychology
# Second Word:  cognition
# Path similarity:  0.16666666666666666
# lch similarity:  1.845826690498331
# wup similarity:  0.6153846153846154
